# %%
import plotly.express as px
import datetime as dt
import pandas as pd
from lunarcalendar import Converter, Solar, Lunar, DateNotExist
from pandas_profiling import ProfileReport

# %%
import itertools
import datetime as dt
from sklearn.metrics import mean_squared_log_error, mean_squared_error

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 2000)
pd.set_option('display.max_colwidth', -1)
# Out:
# /mnt/GVO/space/revenue/env/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning:
#
# Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.

# %%
# %%capture
from tqdm import tqdm_notebook as tqdm
tqdm().pandas()

# %%
import pandas as pd
import numpy as np
import pandas as pd
from fbprophet import Prophet
import datetime as dt
from sklearn import metrics
import math
import itertools
from tqdm import tqdm
from multiprocessing import Pool, cpu_count
from fbprophet.diagnostics import performance_metrics
from fbprophet.diagnostics import cross_validation

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %% [markdown]
# # Read data

# %%
revenue = pd.read_csv("/mnt/GVO/space/revenue/data/DT.csv", encoding='latin-1', sep = "\t")
# revenuet10 = pd.read_csv("DT_20201013.csv", encoding='latin-1', sep = "\t")
revenue = pd.concat([revenue, revenuet10])
revenue.columns = ["soluonghoadon", "soluongkhach", "doanhso", "doanhthu", "giamgiamon", "giamgiahoadon", "giamgiathanhvien", "vat", "phuphi", "macuahang", "tencuahang", "ngay" ]
revenue = revenue[["macuahang", "tencuahang", "ngay", "soluonghoadon", "soluongkhach", "doanhso", "giamgiamon", "giamgiahoadon", "giamgiathanhvien", "vat", "phuphi", "doanhthu"]]
revenue["ngay"] = pd.to_datetime(revenue['ngay'], format="%d/%m/%Y")
revenue["dow"] = revenue["ngay"].dt.dayofweek
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-742bd044c92b> in <module>
# ----> 1 revenue = pd.read_csv("DT.csv", encoding='latin-1', sep = "\t")
#       2 revenuet10 = pd.read_csv("DT_20201013.csv", encoding='latin-1', sep = "\t")
#       3 revenue = pd.concat([revenue, revenuet10])
#       4 revenue.columns = ["soluonghoadon", "soluongkhach", "doanhso", "doanhthu", "giamgiamon", "giamgiahoadon", "giamgiathanhvien", "vat", "phuphi", "macuahang", "tencuahang", "ngay" ]
#       5 revenue = revenue[["macuahang", "tencuahang", "ngay", "soluonghoadon", "soluongkhach", "doanhso", "giamgiamon", "giamgiahoadon", "giamgiathanhvien", "vat", "phuphi", "doanhthu"]]
#
# /mnt/GVO/space/revenue/env/lib/python3.6/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# --> 688     return _read(filepath_or_buffer, kwds)
#     689
#     690
#
# /mnt/GVO/space/revenue/env/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     # Create the parser.
# --> 454     parser = TextFileReader(fp_or_buf, **kwds)
#     455
#     456     if chunksize or iterator:
#
# /mnt/GVO/space/revenue/env/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     946             self.options["has_index_names"] = kwds["has_index_names"]
#     947
# --> 948         self._make_engine(self.engine)
#     949
#     950     def close(self):
#
# /mnt/GVO/space/revenue/env/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1178     def _make_engine(self, engine="c"):
#    1179         if engine == "c":
# -> 1180             self._engine = CParserWrapper(self.f, **self.options)
#    1181         else:
#    1182             if engine == "python":
#
# /mnt/GVO/space/revenue/env/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1991         if kwds.get("compression") is None and encoding:
#    1992             if isinstance(src, str):
# -> 1993                 src = open(src, "rb")
#    1994                 self.handles.append(src)
#    1995
#
# FileNotFoundError: [Errno 2] No such file or directory: 'DT.csv'

# %% [markdown]
# # Prophet

# %%
def nfl_sunday(ds):
    date = ds
    if (date.weekday() == 5):
        return 1
    else:
        return 0

# %%
def nfl_monday(ds):
    date = ds
    if  (date.weekday() == 6)|(date.weekday() == 0):
        return 1
    else:
        return 0

# %%
independent = pd.DataFrame({
  'holiday': 'independent',
  'ds': pd.to_datetime(['2018-09-02', '2019-09-02', '2020-09-02']),
  'lower_window':-1,
  'upper_window': 0,
})

women = pd.DataFrame({
  'holiday': 'women',
  'ds': pd.to_datetime(['2018-03-08', '2018-10-20','2019-03-08', '2019-10-20','2019-11-20', '2020-03-08', '2020-10-20','2020-11-20']),
  'lower_window':-2,
  'upper_window': 0,
})

labor = pd.DataFrame({
  'holiday': 'labor',
  'ds': pd.to_datetime(['2018-04-30', '2018-05-01', '2019-04-30', '2019-05-01']),
  'lower_window':-3,
  'upper_window': 0,
})

xmas = pd.DataFrame({
  'holiday': 'xmas',
  'ds': pd.to_datetime(['2018-12-24', '2018-12-25', '2019-01-01', '2019-12-24', '2019-12-25','2020-01-01', '2020-12-24', '2020-12-25', '2021-01-01']),
  'lower_window':-3,
  'upper_window': 0,
})

holidays = pd.concat((independent, women, labor , xmas))

# %%
params = [[3, 5, 10, 0.5, 10, 0.5],[25, 25, 50, 0.1, 10, 0.1],[50, 30, 60, 0.3, 10, 0.3],[2, 4, 8, 0.8, 10, 0.8],
         [2, 2, 4, 0.8, 10, 0.8], [2, 3, 25, 0.1, 10, 0.1],[5, 2, 2, 0.5, 0.3, 0.01]]

param_grid = {  
    'wseas':[2,3,5,10,25,30,40,50],
    'mseas':[2],
    'yseas':[2,3,5,10,25,30,40,50],
    'seasonality_prior_scale': [0.01, 0.1, 0.3, 0.5, 1.0, 10.0],
    'holiday_prior_scale': [0.01, 0.1, 0.3, 0.5, 1.0, 10.0],
    'changepoint_prior_scale': [0.001, 0.01,0.05,0.1, 0.2, 0.3, 0.5],
    
    
}
all_params = [list(v) for v in itertools.product(*param_grid.values())]

# %%
def build_model(pars):
    wseas, mseas, yseas, s_prior, h_prior,c_prior= pars
    m = Prophet(growth = 'linear',
#                 seasonality_mode='multiplicative',
                holidays=holidays,
                changepoint_range = 0.9,
                daily_seasonality = False,
                weekly_seasonality = False,
                yearly_seasonality = False,
                holidays_prior_scale =h_prior,
                seasonality_prior_scale = s_prior,
                changepoint_prior_scale = c_prior
                   )
        


    m = m.add_seasonality(
        name = 'weekly',
        period=7,
        fourier_order = wseas)

#     m = m.add_seasonality(
#         name = 'monthly',
#         period=30.5,
#         fourier_order = mseas)


    m = m.add_seasonality(
        name = 'yearly',
        period=365.25,
        fourier_order = yseas)
    m.add_regressor('nfl_sunday')
#     m.add_regressor('nfl_monday')
    return m

# %%
def onecolfcst(current_col, params):  
    
    best_error = np.inf
    best_params = ()
    best_val_forecast = 0
    
    current_data = pd.DataFrame({
        'ds' : train.ngay,
        'y' : train[current_col],
        "nfl_sunday": train['nfl_sunday'],
        "nfl_monday": train['nfl_monday']
    })
    rmses = []
    for pars in tqdm(params):
        m = build_model(pars)  
        m.fit(current_data)
        df_cv = cross_validation(m, cutoffs=cutoffs, initial=500, horizon='30 days', parallel="processes")
        curerror = performance_metrics(df_cv, rolling_window=1)['mape'].values[0]
        print(pars, curerror)
        rmses.append(curerror)
    result = pd.DataFrame()
    result["params"] = params
    result["rmse"] = rmses
    return result

# %%
def predict_model(train, test, params, current_col):
    m = build_model(params)   
    current_data = pd.DataFrame({
        'ds' : list(train.ngay),
        'y' : list(train[current_col]),
        'nfl_sunday' : list(train["nfl_sunday"]),
        'nfl_monday' : list(train["nfl_monday"])})
    
    m.fit(current_data)
    
    predict_feature = pd.DataFrame({
            'ds': test.ngay,
            "nfl_sunday": test['nfl_sunday'],
            "nfl_monday": test['nfl_monday']
        })
    realforecast = m.predict(predict_feature)
    return list(realforecast['yhat'])

# %%
def predict_next(train, params, current_col, day = 30):
    m = build_model(params)   
    current_data = pd.DataFrame({
        'ds' : list(train.ngay),
        'y' : list(train[current_col]),
        'nfl_sunday' : list(train["nfl_sunday"]),
        'nfl_monday' : list(train["nfl_monday"])})
    
    m.fit(current_data)
    future = m.make_future_dataframe(periods = day,include_history =False)
    future["nfl_sunday"] = future.ds.apply(nfl_sunday)
    future["nfl_monday"] = future.ds.apply(nfl_monday)
    predict_feature = pd.DataFrame({
            'ds': future.ds,
            "nfl_sunday": future['nfl_sunday'],
            "nfl_monday": future['nfl_monday']
        })
    realforecast = m.predict(predict_feature)
    future["predict"] = list(realforecast['yhat'])
    return future

# %%
cutoffs = pd.to_datetime(['2020-07-31'])

# %%
# store = revenue[revenue.macuahang.isin([1,4,5,6,16,18])]
# store = store[(store.ngay< dt.datetime(2020,3,6))|(store.ngay> dt.datetime(2020,6,16))]
# store = store[store.doanhso!=0]

# %%
store = revenue[revenue.macuahang.isin([1,4,5,6,16,18,19])]
store = store[(store.ngay< dt.datetime(2020,3,6))|(store.ngay> dt.datetime(2020,6,16))]
store = store[store.doanhso!=0]
store =store[(store.macuahang!=19)|((store.macuahang==19)&(store.ngay> dt.datetime(2018,2,3)))]

# %% [markdown]
# ## Ung van khiem

# %%
ungvankhiem = store[store.macuahang==1]

# %%
ungvankhiem
# Out:
#     macuahang           tencuahang       ngay  soluonghoadon  soluongkhach      doanhso  giamgiamon  giamgiahoadon  giamgiathanhvien       vat  phuphi     doanhthu  dow
# 0   1          ICOOL Ung V?n Khiêm 2017-07-25  70             418           86496200.0   923600.0    472120.0       2729705.0         402623.5  0       82370775.0   1
# 7   1          ICOOL Ung V?n Khiêm 2017-07-26  75             481           95504100.0   356000.0    6417750.0      2010085.0         0.0       0       86720265.0   2
# 14  1          ICOOL Ung V?n Khiêm 2017-07-27  76             418           96707700.0   759000.0    1505440.0      1920390.0         119583.0  500000  92522870.0   3
# 21  1          ICOOL Ung V?n Khiêm 2017-07-28  87             596           128260700.0  3134300.0   1105580.0      2474980.0         293317.5  400000  121545840.0  4
# 28  1          ICOOL Ung V?n Khiêm 2017-07-29  109            768           158043700.0  1419000.0   432440.0       3837745.0         133960.0  0       152354515.0  5
# .. ..                          ...        ...  ...            ...                   ...        ...        ...             ...              ... ..               ... ..
# 34  1          ICool Ung V?n Khiêm 2020-10-20  105            723           178692934.0  6492683.3   0.0            121480.0          652490.0  0       172078770.7  1
# 35  1          ICool Ung V?n Khiêm 2020-10-21  60             379           82038000.0   2917470.0   1654000.0      0.0               231312.0  0       77466530.0   2
# 36  1          ICool Ung V?n Khiêm 2020-10-22  66             426           83757400.0   2746320.0   573330.0       0.0               336595.0  0       80437750.0   3
# 37  1          ICool Ung V?n Khiêm 2020-10-23  73             504           107279801.0  4338130.0   1612000.0      0.0               266907.5  0       101329671.0  4
# 38  1          ICool Ung V?n Khiêm 2020-10-24  101            749           176340301.0  6452690.0   11957700.0     463850.0          0.0       0       157466061.0  5
#
# [1099 rows x 13 columns]

# %%
firstday = dt.datetime.strptime('2019/1/1', '%Y/%m/%d').date()
lastday = dt.datetime.strptime('2020/9/30', '%Y/%m/%d').date()

# %%
date_period = pd.date_range(firstday, lastday- dt.timedelta(days = 61))
date_period1 = pd.date_range(lastday- dt.timedelta(days = 60), lastday- dt.timedelta(days = 30))
date_period2 = pd.date_range(lastday- dt.timedelta(days = 29), lastday)

# %%
all_prediod =  pd.date_range(firstday, lastday)
date_test_period =  pd.date_range(dt.datetime.strptime('2020/10/1', '%Y/%m/%d').date(), dt.datetime.strptime('2020/10/31', '%Y/%m/%d').date() )
date_11 =  pd.date_range(dt.datetime.strptime('2020/11/1', '%Y/%m/%d').date(), dt.datetime.strptime('2020/11/20', '%Y/%m/%d').date() )

# %%
date_df =pd.DataFrame(pd.date_range(firstday, dt.datetime.strptime('2020/11/20', '%Y/%m/%d').date() ), columns = ["ngay"])
data_df = date_df.merge(ungvankhiem[["ngay", "doanhthu"]], on = "ngay", how = "left")
# date_df.comlumns

# %%
data_df["nfl_sunday"] = data_df['ngay'].apply(nfl_sunday)
data_df["nfl_monday"] = data_df['ngay'].apply(nfl_monday)

# %%
train = data_df[data_df.ngay.isin(list(date_period)+list(date_period1) + list(date_period2))]
test = data_df[data_df.ngay.isin(date_period2)].reset_index().drop(["index"], axis=1)

# %%
all_data = data_df[data_df.ngay.isin(all_prediod)].reset_index().drop(["index"], axis=1)
all_data_10 = data_df[data_df.ngay.isin(pd.date_range(firstday,dt.datetime.strptime('2020/10/31', '%Y/%m/%d').date()))].reset_index().drop(["index"], axis=1)
backtest = data_df[data_df.ngay.isin(date_test_period)].reset_index().drop(["index"], axis=1)
backtest_11 = data_df[data_df.ngay.isin(date_11)].reset_index().drop(["index"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-57e92d2eb53b> in <module>
# ----> 1 all_data = data_df[data_df.ngay.isin(all_prediod)].reset_index().drop(["index"], axis=1)
#       2 all_data_10 = data_df[data_df.ngay.isin(pd.date_range(firstday,dt.datetime.strptime('2020/10/31', '%Y/%m/%d').date()))].reset_index().drop(["index"], axis=1)
#       3 backtest = data_df[data_df.ngay.isin(date_test_period)].reset_index().drop(["index"], axis=1)
#       4 backtest_11 = data_df[data_df.ngay.isin(date_11)].reset_index().drop(["index"], axis=1)
#
# NameError: name 'data_df' is not defined

# %%
error = onecolfcst("doanhthu", params = params)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f24556d63c8>
#  14%|█▍        | 1/7 [00:02<00:12,  2.09s/it]
# [3, 5, 10, 0.5, 10, 0.5] 0.3681795165106272
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f248f2c7cf8>
#  29%|██▊       | 2/7 [00:04<00:11,  2.28s/it]
# [25, 25, 50, 0.1, 10, 0.1] 0.37336237098525416
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f24534294a8>
#  43%|████▎     | 3/7 [00:07<00:09,  2.40s/it]
# [50, 30, 60, 0.3, 10, 0.3] 0.3726611685660557
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f24534f2860>
#  57%|█████▋    | 4/7 [00:10<00:07,  2.51s/it]INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f24534df940>
# [2, 4, 8, 0.8, 10, 0.8] 0.34308704469153056
#  71%|███████▏  | 5/7 [00:12<00:04,  2.35s/it]
# [2, 2, 4, 0.8, 10, 0.8] 0.29924021718865235
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f24534f2828>
#  86%|████████▌ | 6/7 [00:14<00:02,  2.20s/it]INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f2454ea1a58>
# [2, 3, 25, 0.1, 10, 0.1] 0.36509429784751996
# 100%|██████████| 7/7 [00:15<00:00,  2.26s/it]
# [5, 2, 2, 0.5, 0.3, 0.01] 0.3214040640875949

# %%
best_params = [2, 2, 4, 0.8, 10, 0.8]

# %%
# best_params = error[error.rmse == error.rmse.min()].params.values[0]
backtest["predict"] = predict_model(all_data, backtest,best_params, "doanhthu")

# %%
fig = px.line(backtest, x="ngay", y=["doanhthu","predict"])
fig.show()
# Out:
# <div>                            <div id="a5793cf3-4774-4973-9d28-fbc0c2bd5619" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a5793cf3-4774-4973-9d28-fbc0c2bd5619")) {                    Plotly.newPlot(                        "a5793cf3-4774-4973-9d28-fbc0c2bd5619",                        [{"hovertemplate": "variable=doanhthu<br>ngay=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "doanhthu", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "doanhthu", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-10-01T00:00:00", "2020-10-02T00:00:00", "2020-10-03T00:00:00", "2020-10-04T00:00:00", "2020-10-05T00:00:00", "2020-10-06T00:00:00", "2020-10-07T00:00:00", "2020-10-08T00:00:00", "2020-10-09T00:00:00", "2020-10-10T00:00:00", "2020-10-11T00:00:00", "2020-10-12T00:00:00", "2020-10-13T00:00:00", "2020-10-14T00:00:00", "2020-10-15T00:00:00", "2020-10-16T00:00:00", "2020-10-17T00:00:00", "2020-10-18T00:00:00", "2020-10-19T00:00:00", "2020-10-20T00:00:00", "2020-10-21T00:00:00", "2020-10-22T00:00:00", "2020-10-23T00:00:00", "2020-10-24T00:00:00", "2020-10-25T00:00:00", "2020-10-26T00:00:00", "2020-10-27T00:00:00", "2020-10-28T00:00:00", "2020-10-29T00:00:00", "2020-10-30T00:00:00", "2020-10-31T00:00:00"], "xaxis": "x", "y": [104319640.0, 128951148.0, 208923091.0, 131321973.0, 78347676.0, 112012461.0, 118143810.0, 102563913.5, 116993520.0, 218610171.0, 113425490.0, 86939270.0, 117845970.0, 76683100.0, 84544345.5, 140135971.0, 186769790.0, 137747140.0, 89883229.0, 172078770.7, 77466530.0, 80437750.0, 101329671.0, 157466061.0, 100843585.0, 62050460.0, 71389450.0, 90737362.0, 79878499.4, 145182641.0, 167705745.0], "yaxis": "y"}, {"hovertemplate": "variable=predict<br>ngay=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "predict", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "predict", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-10-01T00:00:00", "2020-10-02T00:00:00", "2020-10-03T00:00:00", "2020-10-04T00:00:00", "2020-10-05T00:00:00", "2020-10-06T00:00:00", "2020-10-07T00:00:00", "2020-10-08T00:00:00", "2020-10-09T00:00:00", "2020-10-10T00:00:00", "2020-10-11T00:00:00", "2020-10-12T00:00:00", "2020-10-13T00:00:00", "2020-10-14T00:00:00", "2020-10-15T00:00:00", "2020-10-16T00:00:00", "2020-10-17T00:00:00", "2020-10-18T00:00:00", "2020-10-19T00:00:00", "2020-10-20T00:00:00", "2020-10-21T00:00:00", "2020-10-22T00:00:00", "2020-10-23T00:00:00", "2020-10-24T00:00:00", "2020-10-25T00:00:00", "2020-10-26T00:00:00", "2020-10-27T00:00:00", "2020-10-28T00:00:00", "2020-10-29T00:00:00", "2020-10-30T00:00:00", "2020-10-31T00:00:00"], "xaxis": "x", "y": [99882833.28584167, 137024167.56338137, 174333663.4007377, 120324642.08313479, 88786381.32244955, 91761503.06325406, 92904034.6663105, 99120200.1306054, 136087345.77081078, 173229555.65246835, 119061081.27914557, 87372092.4958833, 90206060.75784111, 91217815.96915734, 97314333.58033292, 134173656.37753145, 171220506.28637928, 141362715.83781907, 106571708.43577452, 160370072.47928298, 88962481.49877527, 95033251.71871382, 131881719.51244208, 168932757.6725751, 114701267.8922265, 82977927.91519347, 85806571.7267583, 86842244.00755593, 92991985.5498875, 129933754.08037436, 167092035.8164094], "yaxis": "y"}],                        {"legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minor ...

# %%
print("Doanh thu thuc te", backtest.doanhthu.sum())
print("Doanh thu du doan", backtest.predict.sum())
diff_percent = (backtest.doanhthu.sum() - backtest.predict.sum())/backtest.doanhthu.sum()
print("diff_percent", diff_percent)
print("mape", mean_absolute_percentage_error(backtest.doanhthu, backtest.predict))
print("rmse", mean_squared_error(backtest.doanhthu, backtest.predict, squared=False))
# Out:
# Doanh thu thuc te 3660728234.1
# Doanh thu du doan 3657480367.829054
# diff_percent 0.0008872186251609367
# mape 12.963310262118977
# rmse 17541109.557437077

# %%
ungvankhiem_10 = backtest[["ngay", "predict"]]
ungvankhiem_10.columns = ["ngay", "ungvankhiem"]

# %%
backtest_11["predict"] = predict_model(all_data_10, backtest_11,best_params, "doanhthu")
(backtest_11.doanhthu.sum() - backtest_11.predict.sum())/backtest_11.doanhthu.sum()
# Out:
# 0.08851448331237798

# %%
print("Doanh thu thuc te", backtest_11.doanhthu.sum())
print("Doanh thu du doan", backtest_11.predict.sum())
diff_percent = (backtest_11.doanhthu.sum() - backtest_11.predict.sum())/backtest_11.doanhthu.sum()
print("diff_percent", diff_percent)
print("mape", mean_absolute_percentage_error(backtest_11.doanhthu, backtest_11.predict))
print("rmse", mean_squared_error(backtest_11.doanhthu, backtest_11.predict, squared=False))
# Out:
# Doanh thu thuc te 2354301757.8
# Doanh thu du doan 2145911954.14691
# diff_percent 0.08851448331237798
# mape 10.868273056645721
# rmse 15998973.811941458

# %%
ungvankhiem_20_11 = backtest_11[["ngay", "predict"]]
ungvankhiem_20_11.columns = ["ngay", "ungvankhiem"]

# %%
fig = px.line(backtest_11, x="ngay", y=["doanhthu","predict"])
fig.show()
# Out:
# <div>                            <div id="ad2a89b2-0d60-490a-b04f-f31b42371df6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad2a89b2-0d60-490a-b04f-f31b42371df6")) {                    Plotly.newPlot(                        "ad2a89b2-0d60-490a-b04f-f31b42371df6",                        [{"hovertemplate": "variable=doanhthu<br>ngay=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "doanhthu", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "doanhthu", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-11-01T00:00:00", "2020-11-02T00:00:00", "2020-11-03T00:00:00", "2020-11-04T00:00:00", "2020-11-05T00:00:00", "2020-11-06T00:00:00", "2020-11-07T00:00:00", "2020-11-08T00:00:00", "2020-11-09T00:00:00", "2020-11-10T00:00:00", "2020-11-11T00:00:00", "2020-11-12T00:00:00", "2020-11-13T00:00:00", "2020-11-14T00:00:00", "2020-11-15T00:00:00", "2020-11-16T00:00:00", "2020-11-17T00:00:00", "2020-11-18T00:00:00", "2020-11-19T00:00:00", "2020-11-20T00:00:00"], "xaxis": "x", "y": [100390015.0, 75914200.0, 72361870.0, 81589081.0, 98398947.0, 134869197.0, 194376896.0, 108109510.0, 74042680.0, 109033011.0, 113247855.0, 103617690.0, 132368520.0, 175593157.0, 132505142.0, 81007880.0, 102488840.0, 122718770.0, 122725055.0, 218943441.8], "yaxis": "y"}, {"hovertemplate": "variable=predict<br>ngay=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "predict", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "predict", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-11-01T00:00:00", "2020-11-02T00:00:00", "2020-11-03T00:00:00", "2020-11-04T00:00:00", "2020-11-05T00:00:00", "2020-11-06T00:00:00", "2020-11-07T00:00:00", "2020-11-08T00:00:00", "2020-11-09T00:00:00", "2020-11-10T00:00:00", "2020-11-11T00:00:00", "2020-11-12T00:00:00", "2020-11-13T00:00:00", "2020-11-14T00:00:00", "2020-11-15T00:00:00", "2020-11-16T00:00:00", "2020-11-17T00:00:00", "2020-11-18T00:00:00", "2020-11-19T00:00:00", "2020-11-20T00:00:00"], "xaxis": "x", "y": [109938323.16272612, 78200821.25831391, 81812969.66779898, 82806463.44524987, 88254745.12363674, 125464864.52264513, 164249498.9188009, 108795662.2933723, 77281141.23659092, 81123574.74597944, 82353533.06130335, 88043295.39784126, 125498715.08221908, 164531245.223419, 109326653.60606381, 78061464.36369124, 82152043.63761485, 107777855.40951948, 107090348.1516891, 203148735.83843464], "yaxis": "y"}],                        {"legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": ...

# %%
ungvankhiem_12 = predict_next(data_df,best_params,"doanhthu",41)

# %%
ungvankhiem_12 = ungvankhiem_12[["ds", "predict"]]
ungvankhiem_12.columns = ["ds", "ungvankhiem"]

# %% [markdown]
# ## XVNT

# %%
xvnt = store[store.macuahang==4]

firstday = dt.datetime.strptime('2019/1/1', '%Y/%m/%d').date()
lastday = dt.datetime.strptime('2020/9/30', '%Y/%m/%d').date() 

date_period = pd.date_range(firstday, lastday- dt.timedelta(days = 61))
date_period1 = pd.date_range(lastday- dt.timedelta(days = 60), lastday- dt.timedelta(days = 30))
date_period2 = pd.date_range(lastday- dt.timedelta(days = 29), lastday)

all_prediod =  pd.date_range(firstday, lastday)
date_test_period =  pd.date_range(dt.datetime.strptime('2020/10/1', '%Y/%m/%d').date(), dt.datetime.strptime('2020/10/31', '%Y/%m/%d').date() )
date_11 =  pd.date_range(dt.datetime.strptime('2020/11/1', '%Y/%m/%d').date(), dt.datetime.strptime('2020/11/20', '%Y/%m/%d').date() )

date_df =pd.DataFrame(pd.date_range(firstday, dt.datetime.strptime('2020/11/20', '%Y/%m/%d').date() ), columns = ["ngay"])
data_df = date_df.merge(xvnt[["ngay", "doanhthu"]], on = "ngay", how = "left")
# date_df.comlumns

data_df["nfl_sunday"] = data_df['ngay'].apply(nfl_sunday)
data_df["nfl_monday"] = data_df['ngay'].apply(nfl_monday)

train = data_df[data_df.ngay.isin(list(date_period)+list(date_period1) + list(date_period2))]
test = data_df[data_df.ngay.isin(date_period2)].reset_index().drop(["index"], axis=1)

all_data = data_df[data_df.ngay.isin(all_prediod)].reset_index().drop(["index"], axis=1)
all_data_10 = data_df[data_df.ngay.isin(pd.date_range(firstday,dt.datetime.strptime('2020/10/31', '%Y/%m/%d').date()))].reset_index().drop(["index"], axis=1)
backtest = data_df[data_df.ngay.isin(date_test_period)].reset_index().drop(["index"], axis=1)
backtest_11 = data_df[data_df.ngay.isin(date_11)].reset_index().drop(["index"], axis=1)

error = onecolfcst("doanhthu", params = params)

best_params = [6, 3, 6, 0.8, 9, 0.8]

# best_params = error[error.rmse == error.rmse.min()].params.values[0]
backtest["predict"] = predict_model(all_data, backtest,best_params, "doanhthu")

fig = px.line(backtest, x="ngay", y=["doanhthu","predict"])
fig.show()

print("Doanh thu thuc te", backtest.doanhthu.sum())
print("Doanh thu du doan", backtest.predict.sum())
diff_percent = (backtest.doanhthu.sum() - backtest.predict.sum())/backtest.doanhthu.sum()
print("diff_percent", diff_percent)
print("mape", mean_absolute_percentage_error(backtest.doanhthu, backtest.predict))
print("rmse", mean_squared_error(backtest.doanhthu, backtest.predict, squared=False))

xvnt_10 = backtest[["ngay", "predict"]]
xvnt_10.columns = ["ngay", "xvnt"]

backtest_11["predict"] = predict_model(all_data_10, backtest_11,best_params, "doanhthu")
(backtest_11.doanhthu.sum() - backtest_11.predict.sum())/backtest_11.doanhthu.sum()

print("Doanh thu thuc te", backtest_11.doanhthu.sum())
print("Doanh thu du doan", backtest_11.predict.sum())
diff_percent = (backtest_11.doanhthu.sum() - backtest_11.predict.sum())/backtest_11.doanhthu.sum()
print("diff_percent", diff_percent)
print("mape", mean_absolute_percentage_error(backtest_11.doanhthu, backtest_11.predict))
print("rmse", mean_squared_error(backtest_11.doanhthu, backtest_11.predict, squared=False))

xvnt_20_11 = backtest_11[["ngay", "predict"]]
xvnt_20_11.columns = ["ngay", "xvnt"]

fig = px.line(backtest_11, x="ngay", y=["doanhthu","predict"])
fig.show()



xvnt_12 = predict_next(data_df,best_params,"doanhthu",41)

xvnt_12 = xvnt_12[["ds", "predict"]]
xvnt_12.columns = ["ds", "xvnt"]

# %% [markdown]
# ## TOKY

# %%
toky = store[store.macuahang==5]

# %%
firstday = dt.datetime.strptime('2019/1/1', '%Y/%m/%d').date()
lastday = dt.datetime.strptime('2020/9/30', '%Y/%m/%d').date()

# %%
date_period = pd.date_range(firstday, lastday- dt.timedelta(days = 61))
date_period1 = pd.date_range(lastday- dt.timedelta(days = 60), lastday- dt.timedelta(days = 30))
date_period2 = pd.date_range(lastday- dt.timedelta(days = 29), lastday)

# %%
all_prediod =  pd.date_range(firstday, lastday)
date_test_period =  pd.date_range(dt.datetime.strptime('2020/10/1', '%Y/%m/%d').date(), dt.datetime.strptime('2020/10/31', '%Y/%m/%d').date() )
date_11 =  pd.date_range(dt.datetime.strptime('2020/11/1', '%Y/%m/%d').date(), dt.datetime.strptime('2020/11/20', '%Y/%m/%d').date() )

# %%
date_df =pd.DataFrame(pd.date_range(firstday, dt.datetime.strptime('2020/11/20', '%Y/%m/%d').date() ), columns = ["ngay"])
data_df = date_df.merge(toky[["ngay", "doanhthu"]], on = "ngay", how = "left")
# date_df.comlumns

# %%
data_df["nfl_sunday"] = data_df['ngay'].apply(nfl_sunday)
data_df["nfl_monday"] = data_df['ngay'].apply(nfl_monday)

# %%
train = data_df[data_df.ngay.isin(list(date_period)+list(date_period1) + list(date_period2))]
test = data_df[data_df.ngay.isin(date_period2)].reset_index().drop(["index"], axis=1)

# %%
all_data = data_df[data_df.ngay.isin(all_prediod)].reset_index().drop(["index"], axis=1)
all_data_10 = data_df[data_df.ngay.isin(pd.date_range(firstday,dt.datetime.strptime('2020/10/31', '%Y/%m/%d').date()))].reset_index().drop(["index"], axis=1)
backtest = data_df[data_df.ngay.isin(date_test_period)].reset_index().drop(["index"], axis=1)
backtest_11 = data_df[data_df.ngay.isin(date_11)].reset_index().drop(["index"], axis=1)

# %%
error = onecolfcst("doanhthu", params = params)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f245344e358>
#  14%|█▍        | 1/7 [00:01<00:11,  1.97s/it]
# [3, 5, 10, 0.5, 10, 0.5] 0.3288963331790131
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f24534442e8>
#  29%|██▊       | 2/7 [00:04<00:10,  2.10s/it]
# [25, 25, 50, 0.1, 10, 0.1] 0.4230368683878393
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f245341c518>
#  43%|████▎     | 3/7 [00:07<00:09,  2.32s/it]
# [50, 30, 60, 0.3, 10, 0.3] 0.4399606411188455
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f24534cef28>
#  57%|█████▋    | 4/7 [00:09<00:06,  2.27s/it]
# [2, 4, 8, 0.8, 10, 0.8] 0.3123968341086247
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f24534a6c50>
#  71%|███████▏  | 5/7 [00:11<00:04,  2.19s/it]
# [2, 2, 4, 0.8, 10, 0.8] 0.29214872252654467
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f24534a2ac8>
#  86%|████████▌ | 6/7 [00:13<00:02,  2.14s/it]INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f24534a6518>
# [2, 3, 25, 0.1, 10, 0.1] 0.4319884656554507
# 100%|██████████| 7/7 [00:15<00:00,  2.18s/it]
# [5, 2, 2, 0.5, 0.3, 0.01] 0.38341277733303336

# %%
best_params = [2, 3, 2, 0.8, 10, 0.8]

# %%
# best_params = error[error.rmse == error.rmse.min()].params.values[0]
backtest["predict"] = predict_model(all_data, backtest,best_params, "doanhthu")

# %%
fig = px.line(backtest, x="ngay", y=["doanhthu","predict"])
fig.show()
# Out:
# <div>                            <div id="bc44da5e-5707-451b-8383-a7321e86b159" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bc44da5e-5707-451b-8383-a7321e86b159")) {                    Plotly.newPlot(                        "bc44da5e-5707-451b-8383-a7321e86b159",                        [{"hovertemplate": "variable=doanhthu<br>ngay=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "doanhthu", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "doanhthu", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-10-01T00:00:00", "2020-10-02T00:00:00", "2020-10-03T00:00:00", "2020-10-04T00:00:00", "2020-10-05T00:00:00", "2020-10-06T00:00:00", "2020-10-07T00:00:00", "2020-10-08T00:00:00", "2020-10-09T00:00:00", "2020-10-10T00:00:00", "2020-10-11T00:00:00", "2020-10-12T00:00:00", "2020-10-13T00:00:00", "2020-10-14T00:00:00", "2020-10-15T00:00:00", "2020-10-16T00:00:00", "2020-10-17T00:00:00", "2020-10-18T00:00:00", "2020-10-19T00:00:00", "2020-10-20T00:00:00", "2020-10-21T00:00:00", "2020-10-22T00:00:00", "2020-10-23T00:00:00", "2020-10-24T00:00:00", "2020-10-25T00:00:00", "2020-10-26T00:00:00", "2020-10-27T00:00:00", "2020-10-28T00:00:00", "2020-10-29T00:00:00", "2020-10-30T00:00:00", "2020-10-31T00:00:00"], "xaxis": "x", "y": [30378846.0, 37045138.0, 74246768.0, 64292891.0, 39762419.0, 31144465.0, 27472278.0, 27624451.0, 48601969.0, 52758365.0, 67393605.0, 22277600.0, 24230977.0, 26369410.0, 20392791.0, 39393289.0, 62340448.0, 41353760.0, 20805350.0, 57973096.0, 10800654.0, 21544075.5, 44495432.0, 62674360.0, 54210933.0, 19935892.0, 8095290.0, 23794617.0, 22458545.0, 39131310.0, 30400439.0], "yaxis": "y"}, {"hovertemplate": "variable=predict<br>ngay=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "predict", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "predict", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-10-01T00:00:00", "2020-10-02T00:00:00", "2020-10-03T00:00:00", "2020-10-04T00:00:00", "2020-10-05T00:00:00", "2020-10-06T00:00:00", "2020-10-07T00:00:00", "2020-10-08T00:00:00", "2020-10-09T00:00:00", "2020-10-10T00:00:00", "2020-10-11T00:00:00", "2020-10-12T00:00:00", "2020-10-13T00:00:00", "2020-10-14T00:00:00", "2020-10-15T00:00:00", "2020-10-16T00:00:00", "2020-10-17T00:00:00", "2020-10-18T00:00:00", "2020-10-19T00:00:00", "2020-10-20T00:00:00", "2020-10-21T00:00:00", "2020-10-22T00:00:00", "2020-10-23T00:00:00", "2020-10-24T00:00:00", "2020-10-25T00:00:00", "2020-10-26T00:00:00", "2020-10-27T00:00:00", "2020-10-28T00:00:00", "2020-10-29T00:00:00", "2020-10-30T00:00:00", "2020-10-31T00:00:00"], "xaxis": "x", "y": [24658664.397193454, 37743121.61568124, 58023441.36477668, 47423147.113317356, 25024351.78003628, 23362033.67224899, 27785384.07668292, 25527329.878979336, 38626314.12443311, 58920577.07695989, 48333620.36199371, 25947535.83431489, 24297281.544093553, 28732029.352341857, 26484687.575452596, 39593681.56928756, 59897234.810466945, 41979509.29016929, 37662132.690608785, 61539986.15112957, 29738350.64077792, 27496483.054105476, 40610151.117245756, 60917568.3683846, 50342211.671462454, 27966150.11562088, 26324321.01100537, 30765877.531346194, 28523711.383349355, 41636233.41284739, 61941654.70562877], "yaxis": "y"}],                        {"legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "whi ...

# %%
print("Doanh thu thuc te", backtest.doanhthu.sum())
print("Doanh thu du doan", backtest.predict.sum())
diff_percent = (backtest.doanhthu.sum() - backtest.predict.sum())/backtest.doanhthu.sum()
print("diff_percent", diff_percent)
print("mape", mean_absolute_percentage_error(backtest.doanhthu, backtest.predict))
print("rmse", mean_squared_error(backtest.doanhthu, backtest.predict, squared=False))
# Out:
# Doanh thu thuc te 1153399463.5
# Doanh thu du doan 1187824777.2919421
# diff_percent -0.02984682660374943
# mape 32.333125472032485
# rmse 10827059.830142789

# %%
backtest_11["predict"] = predict_model(all_data_10, backtest_11,best_params, "doanhthu")
(backtest_11.doanhthu.sum() - backtest_11.predict.sum())/backtest_11.doanhthu.sum()
# Out:
# 0.04845976762369945

# %%
print("Doanh thu thuc te", backtest_11.doanhthu.sum())
print("Doanh thu du doan", backtest_11.predict.sum())
diff_percent = (backtest_11.doanhthu.sum() - backtest_11.predict.sum())/backtest_11.doanhthu.sum()
print("diff_percent", diff_percent)
print("mape", mean_absolute_percentage_error(backtest_11.doanhthu, backtest_11.predict))
print("rmse", mean_squared_error(backtest_11.doanhthu, backtest_11.predict, squared=False))
# Out:
# Doanh thu thuc te 772723209.8
# Doanh thu du doan 735277222.6156528
# diff_percent 0.04845976762369945
# mape 18.230790113975726
# rmse 9997556.674802288

# %%
fig = px.line(backtest_11, x="ngay", y=["doanhthu","predict"])
fig.show()
# Out:
# <div>                            <div id="8e0cb162-84a7-4356-87f0-409fc0911a5c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8e0cb162-84a7-4356-87f0-409fc0911a5c")) {                    Plotly.newPlot(                        "8e0cb162-84a7-4356-87f0-409fc0911a5c",                        [{"hovertemplate": "variable=doanhthu<br>ngay=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "doanhthu", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "doanhthu", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-11-01T00:00:00", "2020-11-02T00:00:00", "2020-11-03T00:00:00", "2020-11-04T00:00:00", "2020-11-05T00:00:00", "2020-11-06T00:00:00", "2020-11-07T00:00:00", "2020-11-08T00:00:00", "2020-11-09T00:00:00", "2020-11-10T00:00:00", "2020-11-11T00:00:00", "2020-11-12T00:00:00", "2020-11-13T00:00:00", "2020-11-14T00:00:00", "2020-11-15T00:00:00", "2020-11-16T00:00:00", "2020-11-17T00:00:00", "2020-11-18T00:00:00", "2020-11-19T00:00:00", "2020-11-20T00:00:00"], "xaxis": "x", "y": [54882619.0, 27752024.0, 28052964.0, 19995998.0, 39053582.0, 34874555.0, 67727168.0, 34843226.8, 23559626.0, 31056785.0, 31322843.0, 25900885.0, 39372371.0, 92483016.0, 51270270.0, 18942512.0, 21024299.0, 26162152.0, 39852000.0, 64594314.0], "yaxis": "y"}, {"hovertemplate": "variable=predict<br>ngay=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "predict", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "predict", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-11-01T00:00:00", "2020-11-02T00:00:00", "2020-11-03T00:00:00", "2020-11-04T00:00:00", "2020-11-05T00:00:00", "2020-11-06T00:00:00", "2020-11-07T00:00:00", "2020-11-08T00:00:00", "2020-11-09T00:00:00", "2020-11-10T00:00:00", "2020-11-11T00:00:00", "2020-11-12T00:00:00", "2020-11-13T00:00:00", "2020-11-14T00:00:00", "2020-11-15T00:00:00", "2020-11-16T00:00:00", "2020-11-17T00:00:00", "2020-11-18T00:00:00", "2020-11-19T00:00:00", "2020-11-20T00:00:00"], "xaxis": "x", "y": [48674060.01732399, 25720403.925260145, 23785635.58062843, 28162179.61185266, 25912793.7887551, 39300245.13123249, 59167518.78185938, 49096018.07976903, 26132254.303659227, 24186723.411865618, 28551857.684416257, 26290423.40454748, 39665196.95887489, 59519173.70066804, 49433768.01225913, 26455503.037274834, 24494887.407465033, 21540795.47230167, 33563392.92020017, 75624391.38543919], "yaxis": "y"}],                        {"legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d08 ...

# %%
toky_10 = backtest[["ngay", "predict"]]
toky_10.columns = ["ngay", "toky"]
toky_20_11 = backtest_11[["ngay", "predict"]]
toky_20_11.columns = ["ngay", "toky"]

# %%
toky_12 = predict_next(data_df,best_params,"doanhthu",41)

# %%
toky_12 = toky_12[["ds", "predict"]]
toky_12.columns = ["ds", "toky"]

# %% [markdown]
# ## binhphu

# %%
binhphu = store[store.macuahang==6]

# %%
firstday = dt.datetime.strptime('2019/1/1', '%Y/%m/%d').date()
lastday = dt.datetime.strptime('2020/9/30', '%Y/%m/%d').date()

# %%
date_period = pd.date_range(firstday, lastday- dt.timedelta(days = 61))
date_period1 = pd.date_range(lastday- dt.timedelta(days = 60), lastday- dt.timedelta(days = 30))
date_period2 = pd.date_range(lastday- dt.timedelta(days = 29), lastday)

# %%
all_prediod =  pd.date_range(firstday, lastday)
date_test_period =  pd.date_range(dt.datetime.strptime('2020/10/1', '%Y/%m/%d').date(), dt.datetime.strptime('2020/10/31', '%Y/%m/%d').date() )
date_11 =  pd.date_range(dt.datetime.strptime('2020/11/1', '%Y/%m/%d').date(), dt.datetime.strptime('2020/11/20', '%Y/%m/%d').date() )

# %%
date_df =pd.DataFrame(pd.date_range(firstday, dt.datetime.strptime('2020/11/20', '%Y/%m/%d').date() ), columns = ["ngay"])
data_df = date_df.merge(binhphu[["ngay", "doanhthu"]], on = "ngay", how = "left")
# date_df.comlumns

# %%
data_df["nfl_sunday"] = data_df['ngay'].apply(nfl_sunday)
data_df["nfl_monday"] = data_df['ngay'].apply(nfl_monday)

# %%
train = data_df[data_df.ngay.isin(list(date_period)+list(date_period1) + list(date_period2))]
test = data_df[data_df.ngay.isin(date_period2)].reset_index().drop(["index"], axis=1)

# %%
all_data = data_df[data_df.ngay.isin(all_prediod)].reset_index().drop(["index"], axis=1)
all_data_10 = data_df[data_df.ngay.isin(pd.date_range(firstday,dt.datetime.strptime('2020/10/31', '%Y/%m/%d').date()))].reset_index().drop(["index"], axis=1)
backtest = data_df[data_df.ngay.isin(date_test_period)].reset_index().drop(["index"], axis=1)
backtest_11 = data_df[data_df.ngay.isin(date_11)].reset_index().drop(["index"], axis=1)

# %%
error = onecolfcst("doanhthu", params = params)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f2453463cc0>
#  14%|█▍        | 1/7 [00:02<00:14,  2.42s/it]
# [3, 5, 10, 0.5, 10, 0.5] 0.3093012318096393
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f24553edc88>
#  29%|██▊       | 2/7 [00:05<00:12,  2.47s/it]
# [25, 25, 50, 0.1, 10, 0.1] 0.28563861743330393
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f24534a6550>
#  43%|████▎     | 3/7 [00:09<00:12,  3.15s/it]
# [50, 30, 60, 0.3, 10, 0.3] 0.3393055963505036
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f24534f21d0>
#  57%|█████▋    | 4/7 [00:11<00:08,  2.87s/it]
# [2, 4, 8, 0.8, 10, 0.8] 0.2857113273907119
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f24534a6b38>
#  71%|███████▏  | 5/7 [00:14<00:05,  2.67s/it]
# [2, 2, 4, 0.8, 10, 0.8] 0.25516640028398996
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f24534a60f0>
#  86%|████████▌ | 6/7 [00:16<00:02,  2.50s/it]INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f245344e240>
# [2, 3, 25, 0.1, 10, 0.1] 0.3025328295807638
# 100%|██████████| 7/7 [00:18<00:00,  2.58s/it]
# [5, 2, 2, 0.5, 0.3, 0.01] 0.3484840392911539

# %%
best_params = [2, 3, 2, 0.8, 9, 0.8]

# %%
# best_params = error[error.rmse == error.rmse.min()].params.values[0]
backtest["predict"] = predict_model(all_data, backtest,best_params, "doanhthu")

# %%
fig = px.line(backtest, x="ngay", y=["doanhthu","predict"])
fig.show()
# Out:
# <div>                            <div id="6c3ab350-d1f8-4067-9c44-dce899326981" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c3ab350-d1f8-4067-9c44-dce899326981")) {                    Plotly.newPlot(                        "6c3ab350-d1f8-4067-9c44-dce899326981",                        [{"hovertemplate": "variable=doanhthu<br>ngay=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "doanhthu", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "doanhthu", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-10-01T00:00:00", "2020-10-02T00:00:00", "2020-10-03T00:00:00", "2020-10-04T00:00:00", "2020-10-05T00:00:00", "2020-10-06T00:00:00", "2020-10-07T00:00:00", "2020-10-08T00:00:00", "2020-10-09T00:00:00", "2020-10-10T00:00:00", "2020-10-11T00:00:00", "2020-10-12T00:00:00", "2020-10-13T00:00:00", "2020-10-14T00:00:00", "2020-10-15T00:00:00", "2020-10-16T00:00:00", "2020-10-17T00:00:00", "2020-10-18T00:00:00", "2020-10-19T00:00:00", "2020-10-20T00:00:00", "2020-10-21T00:00:00", "2020-10-22T00:00:00", "2020-10-23T00:00:00", "2020-10-24T00:00:00", "2020-10-25T00:00:00", "2020-10-26T00:00:00", "2020-10-27T00:00:00", "2020-10-28T00:00:00", "2020-10-29T00:00:00", "2020-10-30T00:00:00", "2020-10-31T00:00:00"], "xaxis": "x", "y": [46800678.0, 68895259.25, 105512989.2, 85887742.4, 40564976.8, 55585721.0, 44063734.0, 55564477.5, 115768550.0, 105366270.0, 62920593.0, 47492032.6, 29444821.0, 36638654.0, 52584010.0, 68210503.45, 108187071.0, 75022421.0, 42626768.0, 69269151.0, 40791795.2, 29169495.0, 75106753.0, 104447978.0, 78043186.5, 26508724.0, 25644649.0, 46567126.0, 39979900.0, 70850840.8, 100740803.3], "yaxis": "y"}, {"hovertemplate": "variable=predict<br>ngay=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "predict", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "predict", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-10-01T00:00:00", "2020-10-02T00:00:00", "2020-10-03T00:00:00", "2020-10-04T00:00:00", "2020-10-05T00:00:00", "2020-10-06T00:00:00", "2020-10-07T00:00:00", "2020-10-08T00:00:00", "2020-10-09T00:00:00", "2020-10-10T00:00:00", "2020-10-11T00:00:00", "2020-10-12T00:00:00", "2020-10-13T00:00:00", "2020-10-14T00:00:00", "2020-10-15T00:00:00", "2020-10-16T00:00:00", "2020-10-17T00:00:00", "2020-10-18T00:00:00", "2020-10-19T00:00:00", "2020-10-20T00:00:00", "2020-10-21T00:00:00", "2020-10-22T00:00:00", "2020-10-23T00:00:00", "2020-10-24T00:00:00", "2020-10-25T00:00:00", "2020-10-26T00:00:00", "2020-10-27T00:00:00", "2020-10-28T00:00:00", "2020-10-29T00:00:00", "2020-10-30T00:00:00", "2020-10-31T00:00:00"], "xaxis": "x", "y": [51309744.25500827, 69590594.37436698, 92744181.77028382, 78619584.50983118, 49577039.36712677, 47188433.2423488, 53456408.48718658, 53133770.40557592, 71434796.93452646, 94607727.0004466, 80501599.75688083, 51476613.99673315, 49104619.62216331, 55388223.01742875, 55080194.59773152, 73394778.5359533, 96580181.16377476, 72571171.03970262, 62219012.2233228, 85792275.54972397, 57399110.38882804, 57097685.26913601, 75417618.98402163, 98607094.59135625, 84515098.06436524, 55501777.77625409, 53138936.03986167, 59429134.54681355, 59125101.979450494, 77441043.7968977, 100625130.69181725], "yaxis": "y"}],                        {"legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", " ...

# %%
print("Doanh thu thuc te", backtest.doanhthu.sum())
print("Doanh thu du doan", backtest.predict.sum())
diff_percent = (backtest.doanhthu.sum() - backtest.predict.sum())/backtest.doanhthu.sum()
print("diff_percent", diff_percent)
print("mape", mean_absolute_percentage_error(backtest.doanhthu, backtest.predict))
print("rmse", mean_squared_error(backtest.doanhthu, backtest.predict, squared=False))
# Out:
# Doanh thu thuc te 1954257674.0
# Doanh thu du doan 2122068681.9789183
# diff_percent -0.08586943790039753
# mape 27.27176464468002
# rmse 15822946.450290486

# %%
backtest_11["predict"] = predict_model(all_data_10, backtest_11,best_params, "doanhthu")
(backtest_11.doanhthu.sum() - backtest_11.predict.sum())/backtest_11.doanhthu.sum()
# Out:
# -0.03137346661192275

# %%
print("Doanh thu thuc te", backtest_11.doanhthu.sum())
print("Doanh thu du doan", backtest_11.predict.sum())
diff_percent = (backtest_11.doanhthu.sum() - backtest_11.predict.sum())/backtest_11.doanhthu.sum()
print("diff_percent", diff_percent)
print("mape", mean_absolute_percentage_error(backtest_11.doanhthu, backtest_11.predict))
print("rmse", mean_squared_error(backtest_11.doanhthu, backtest_11.predict, squared=False))
# Out:
# Doanh thu thuc te 1224589595.45
# Doanh thu du doan 1263009216.2361586
# diff_percent -0.03137346661192275
# mape 16.49884081637662
# rmse 10849882.10982869

# %%
fig = px.line(backtest_11, x="ngay", y=["doanhthu","predict"])
fig.show()
# Out:
# <div>                            <div id="d19dca63-2fa3-421f-81c4-0b2986a01ea6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d19dca63-2fa3-421f-81c4-0b2986a01ea6")) {                    Plotly.newPlot(                        "d19dca63-2fa3-421f-81c4-0b2986a01ea6",                        [{"hovertemplate": "variable=doanhthu<br>ngay=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "doanhthu", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "doanhthu", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-11-01T00:00:00", "2020-11-02T00:00:00", "2020-11-03T00:00:00", "2020-11-04T00:00:00", "2020-11-05T00:00:00", "2020-11-06T00:00:00", "2020-11-07T00:00:00", "2020-11-08T00:00:00", "2020-11-09T00:00:00", "2020-11-10T00:00:00", "2020-11-11T00:00:00", "2020-11-12T00:00:00", "2020-11-13T00:00:00", "2020-11-14T00:00:00", "2020-11-15T00:00:00", "2020-11-16T00:00:00", "2020-11-17T00:00:00", "2020-11-18T00:00:00", "2020-11-19T00:00:00", "2020-11-20T00:00:00"], "xaxis": "x", "y": [73889328.8, 43901579.0, 34161861.5, 34627426.0, 54745596.8, 61251378.0, 101201946.8, 76227396.0, 37773170.6, 44849191.8, 41560487.0, 44752368.8, 60670932.0, 100608315.0, 69260363.9, 38969655.0, 50283582.0, 50516682.0, 73867505.25, 131470829.2], "yaxis": "y"}, {"hovertemplate": "variable=predict<br>ngay=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "predict", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "predict", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-11-01T00:00:00", "2020-11-02T00:00:00", "2020-11-03T00:00:00", "2020-11-04T00:00:00", "2020-11-05T00:00:00", "2020-11-06T00:00:00", "2020-11-07T00:00:00", "2020-11-08T00:00:00", "2020-11-09T00:00:00", "2020-11-10T00:00:00", "2020-11-11T00:00:00", "2020-11-12T00:00:00", "2020-11-13T00:00:00", "2020-11-14T00:00:00", "2020-11-15T00:00:00", "2020-11-16T00:00:00", "2020-11-17T00:00:00", "2020-11-18T00:00:00", "2020-11-19T00:00:00", "2020-11-20T00:00:00"], "xaxis": "x", "y": [78100243.71794258, 48240930.795650035, 45838305.52151408, 51834790.953813635, 51453025.87231429, 70553582.30578548, 93730927.42799413, 78607417.44404624, 48724858.589251876, 46298017.70320964, 52269328.99530738, 51861443.67628102, 70934947.47627503, 94084322.53012362, 78931941.24998827, 49019627.311200686, 46562166.20994448, 44913183.85603258, 57676205.71097579, 103373948.8885076], "yaxis": "y"}],                        {"legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0 ...

# %%
binhphu_10 = backtest[["ngay", "predict"]]
binhphu_10.columns = ["ngay", "binhphu"]
binhphu_20_11 = backtest_11[["ngay", "predict"]]
binhphu_20_11.columns = ["ngay", "binhphu"]

# %%
binhphu_12 = predict_next(data_df,best_params,"doanhthu",41)

# %%
binhphu_12 = binhphu_12[["ds", "predict"]]
binhphu_12.columns = ["ds", "binhphu"]

# %% [markdown]
# ## cauchuy

# %%
cauchuy = store[store.macuahang==16]

# %%
firstday = dt.datetime.strptime('2019/1/1', '%Y/%m/%d').date()
lastday = dt.datetime.strptime('2020/9/30', '%Y/%m/%d').date()

# %%
date_period = pd.date_range(firstday, lastday- dt.timedelta(days = 61))
date_period1 = pd.date_range(lastday- dt.timedelta(days = 60), lastday- dt.timedelta(days = 30))
date_period2 = pd.date_range(lastday- dt.timedelta(days = 29), lastday)

# %%
all_prediod =  pd.date_range(firstday, lastday)
date_test_period =  pd.date_range(dt.datetime.strptime('2020/10/1', '%Y/%m/%d').date(), dt.datetime.strptime('2020/10/31', '%Y/%m/%d').date() )
date_11 =  pd.date_range(dt.datetime.strptime('2020/11/1', '%Y/%m/%d').date(), dt.datetime.strptime('2020/11/20', '%Y/%m/%d').date() )

# %%
date_df =pd.DataFrame(pd.date_range(firstday, dt.datetime.strptime('2020/11/20', '%Y/%m/%d').date() ), columns = ["ngay"])
data_df = date_df.merge(cauchuy[["ngay", "doanhthu"]], on = "ngay", how = "left")
# date_df.comlumns

# %%
data_df["nfl_sunday"] = data_df['ngay'].apply(nfl_sunday)
data_df["nfl_monday"] = data_df['ngay'].apply(nfl_monday)

# %%
train = data_df[data_df.ngay.isin(list(date_period)+list(date_period1) + list(date_period2))]
test = data_df[data_df.ngay.isin(date_period2)].reset_index().drop(["index"], axis=1)

# %%
all_data = data_df[data_df.ngay.isin(all_prediod)].reset_index().drop(["index"], axis=1)
all_data_10 = data_df[data_df.ngay.isin(pd.date_range(firstday,dt.datetime.strptime('2020/10/31', '%Y/%m/%d').date()))].reset_index().drop(["index"], axis=1)
backtest = data_df[data_df.ngay.isin(date_test_period)].reset_index().drop(["index"], axis=1)
backtest_11 = data_df[data_df.ngay.isin(date_11)].reset_index().drop(["index"], axis=1)

# %%
error = onecolfcst("doanhthu", params = params)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f24553ae400>
#  14%|█▍        | 1/7 [00:01<00:11,  1.96s/it]
# [3, 5, 10, 0.5, 10, 0.5] 0.42328484132715166
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f2455094e80>
#  29%|██▊       | 2/7 [00:04<00:10,  2.14s/it]
# [25, 25, 50, 0.1, 10, 0.1] 0.45689029610654625
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f2455618470>
#  43%|████▎     | 3/7 [00:07<00:09,  2.36s/it]
# [50, 30, 60, 0.3, 10, 0.3] 0.4508459144061622
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f2455cc7320>
#  57%|█████▋    | 4/7 [00:09<00:06,  2.26s/it]
# [2, 4, 8, 0.8, 10, 0.8] 0.45048764912356154
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f2455cc74e0>
#  71%|███████▏  | 5/7 [00:11<00:04,  2.18s/it]INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f2455cc7128>
# [2, 2, 4, 0.8, 10, 0.8] 0.47351943461898205
#  86%|████████▌ | 6/7 [00:13<00:02,  2.10s/it]INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f2455b31cf8>
# [2, 3, 25, 0.1, 10, 0.1] 0.5266048645308966
# 100%|██████████| 7/7 [00:15<00:00,  2.15s/it]
# [5, 2, 2, 0.5, 0.3, 0.01] 0.5065200882674072

# %%
best_params = [2, 3, 2, 0.8, 9, 0.8]

# %%
# best_params = error[error.rmse == error.rmse.min()].params.values[0]
backtest["predict"] = predict_model(all_data, backtest,best_params, "doanhthu")

# %%
fig = px.line(backtest, x="ngay", y=["doanhthu","predict"])
fig.show()
# Out:
# <div>                            <div id="b6602cd9-1bcc-4afe-80d8-fcc6c00a96d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b6602cd9-1bcc-4afe-80d8-fcc6c00a96d1")) {                    Plotly.newPlot(                        "b6602cd9-1bcc-4afe-80d8-fcc6c00a96d1",                        [{"hovertemplate": "variable=doanhthu<br>ngay=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "doanhthu", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "doanhthu", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-10-01T00:00:00", "2020-10-02T00:00:00", "2020-10-03T00:00:00", "2020-10-04T00:00:00", "2020-10-05T00:00:00", "2020-10-06T00:00:00", "2020-10-07T00:00:00", "2020-10-08T00:00:00", "2020-10-09T00:00:00", "2020-10-10T00:00:00", "2020-10-11T00:00:00", "2020-10-12T00:00:00", "2020-10-13T00:00:00", "2020-10-14T00:00:00", "2020-10-15T00:00:00", "2020-10-16T00:00:00", "2020-10-17T00:00:00", "2020-10-18T00:00:00", "2020-10-19T00:00:00", "2020-10-20T00:00:00", "2020-10-21T00:00:00", "2020-10-22T00:00:00", "2020-10-23T00:00:00", "2020-10-24T00:00:00", "2020-10-25T00:00:00", "2020-10-26T00:00:00", "2020-10-27T00:00:00", "2020-10-28T00:00:00", "2020-10-29T00:00:00", "2020-10-30T00:00:00", "2020-10-31T00:00:00"], "xaxis": "x", "y": [13231600.0, 17575580.0, 21265928.0, 14997130.0, 8799352.0, 12976512.0, 16470558.0, 7341000.0, 14861504.0, 24602512.0, 17152600.0, null, 11955500.0, 7684900.0, 4847908.0, 13159164.0, 17615256.0, 9246468.0, 11088160.0, 20710830.0, 2869400.0, 5447240.0, 7053200.0, 20743760.0, 20802664.0, 10697800.0, 6465400.0, 10689322.0, 8129020.0, 18191600.0, 20332780.0], "yaxis": "y"}, {"hovertemplate": "variable=predict<br>ngay=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "predict", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "predict", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-10-01T00:00:00", "2020-10-02T00:00:00", "2020-10-03T00:00:00", "2020-10-04T00:00:00", "2020-10-05T00:00:00", "2020-10-06T00:00:00", "2020-10-07T00:00:00", "2020-10-08T00:00:00", "2020-10-09T00:00:00", "2020-10-10T00:00:00", "2020-10-11T00:00:00", "2020-10-12T00:00:00", "2020-10-13T00:00:00", "2020-10-14T00:00:00", "2020-10-15T00:00:00", "2020-10-16T00:00:00", "2020-10-17T00:00:00", "2020-10-18T00:00:00", "2020-10-19T00:00:00", "2020-10-20T00:00:00", "2020-10-21T00:00:00", "2020-10-22T00:00:00", "2020-10-23T00:00:00", "2020-10-24T00:00:00", "2020-10-25T00:00:00", "2020-10-26T00:00:00", "2020-10-27T00:00:00", "2020-10-28T00:00:00", "2020-10-29T00:00:00", "2020-10-30T00:00:00", "2020-10-31T00:00:00"], "xaxis": "x", "y": [8254086.437122082, 12719242.558470553, 18474232.772837106, 12793733.492895868, 7731849.623669291, 7808291.238217809, 8300886.571585785, 8340243.80303679, 12806338.74737161, 18562334.69954983, 12882904.872134207, 7822150.875490051, 7899779.398214509, 8393615.205458838, 8434262.926006166, 12901694.748385355, 18659070.270383917, 10908307.76977146, 8901634.85611305, 17936886.282461554, 8496219.831655681, 8538402.997177254, 13007389.570336457, 18766335.09977375, 13089904.957004517, 8032192.827111157, 8112897.39982675, 8609835.378661739, 8653603.27884095, 13124165.134330526, 18884672.35825233], "yaxis": "y"}],                        {"legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor" ...

# %%
print("Doanh thu thuc te", backtest.doanhthu.sum())
print("Doanh thu du doan", backtest.predict.sum())
diff_percent = (backtest.doanhthu.sum() - backtest.predict.sum())/backtest.doanhthu.sum()
print("diff_percent", diff_percent)
print("mape", mean_absolute_percentage_error(backtest.doanhthu, backtest.predict))
print("rmse", mean_squared_error(backtest.doanhthu, backtest.predict, squared=False))
# Out:
# Doanh thu thuc te 397004648.0
# Doanh thu du doan 357847165.98214704
# diff_percent 0.09863230119626448
# mape 31.42535773939467
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-786-aa965020a524> in <module>
#       4 print("diff_percent", diff_percent)
#       5 print("mape", mean_absolute_percentage_error(backtest.doanhthu, backtest.predict))
# ----> 6 print("rmse", mean_squared_error(backtest.doanhthu, backtest.predict, squared=False))
#
# ~/anaconda3/envs/quochb/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/anaconda3/envs/quochb/lib/python3.6/site-packages/sklearn/metrics/_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     254     """
#     255     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 256         y_true, y_pred, multioutput)
#     257     check_consistent_length(y_true, y_pred, sample_weight)
#     258     output_errors = np.average((y_true - y_pred) ** 2, axis=0,
#
# ~/anaconda3/envs/quochb/lib/python3.6/site-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      83     """
#      84     check_consistent_length(y_true, y_pred)
# ---> 85     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      86     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#      87
#
# ~/anaconda3/envs/quochb/lib/python3.6/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/anaconda3/envs/quochb/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     643         if force_all_finite:
#     644             _assert_all_finite(array,
# --> 645                                allow_nan=force_all_finite == 'allow-nan')
#     646
#     647     if ensure_min_samples > 0:
#
# ~/anaconda3/envs/quochb/lib/python3.6/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      97                     msg_err.format
#      98                     (type_err,
# ---> 99                      msg_dtype if msg_dtype is not None else X.dtype)
#     100             )
#     101     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
backtest_11["predict"] = predict_model(all_data_10, backtest_11,best_params, "doanhthu")
(backtest_11.doanhthu.sum() - backtest_11.predict.sum())/backtest_11.doanhthu.sum()
# Out:
# -0.040235786161102356

# %%
# print("Doanh thu thuc te", backtest_11.doanhthu.sum())
# print("Doanh thu du doan", backtest_11.predict.sum())
# diff_percent = (backtest_11.doanhthu.sum() - backtest_11.predict.sum())/backtest_11.doanhthu.sum()
# print("diff_percent", diff_percent)
# print("mape", mean_absolute_percentage_error(backtest_11.doanhthu, backtest_11.predict))
# print("rmse", mean_squared_error(backtest_11.doanhthu, backtest_11.predict, squared=False))

# %%
fig = px.line(backtest_11, x="ngay", y=["doanhthu","predict"])
fig.show()
# Out:
# <div>                            <div id="64f2213c-98db-4991-ad56-e54b72457730" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64f2213c-98db-4991-ad56-e54b72457730")) {                    Plotly.newPlot(                        "64f2213c-98db-4991-ad56-e54b72457730",                        [{"hovertemplate": "variable=doanhthu<br>ngay=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "doanhthu", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "doanhthu", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-11-01T00:00:00", "2020-11-02T00:00:00", "2020-11-03T00:00:00", "2020-11-04T00:00:00", "2020-11-05T00:00:00", "2020-11-06T00:00:00", "2020-11-07T00:00:00", "2020-11-08T00:00:00", "2020-11-09T00:00:00", "2020-11-10T00:00:00", "2020-11-11T00:00:00", "2020-11-12T00:00:00", "2020-11-13T00:00:00", "2020-11-14T00:00:00", "2020-11-15T00:00:00", "2020-11-16T00:00:00", "2020-11-17T00:00:00", "2020-11-18T00:00:00", "2020-11-19T00:00:00", "2020-11-20T00:00:00"], "xaxis": "x", "y": [20711800.0, 10163880.0, 9927400.0, 4293240.0, 13761000.0, 13425900.0, 31822420.0, 15764600.0, 6467800.0, 20017240.0, 10510000.0, 6799400.0, null, null, null, 41073960.0, 4194400.0, 7381400.0, 12690700.0, 22160120.0], "yaxis": "y"}, {"hovertemplate": "variable=predict<br>ngay=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "predict", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "predict", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-11-01T00:00:00", "2020-11-02T00:00:00", "2020-11-03T00:00:00", "2020-11-04T00:00:00", "2020-11-05T00:00:00", "2020-11-06T00:00:00", "2020-11-07T00:00:00", "2020-11-08T00:00:00", "2020-11-09T00:00:00", "2020-11-10T00:00:00", "2020-11-11T00:00:00", "2020-11-12T00:00:00", "2020-11-13T00:00:00", "2020-11-14T00:00:00", "2020-11-15T00:00:00", "2020-11-16T00:00:00", "2020-11-17T00:00:00", "2020-11-18T00:00:00", "2020-11-19T00:00:00", "2020-11-20T00:00:00"], "xaxis": "x", "y": [14667887.777622346, 9559512.379482392, 9685494.349236833, 10131128.88997522, 10098227.959823044, 14704684.306996852, 20540021.19927156, 14924857.00072269, 9817159.289271014, 9943742.0633932, 10389896.913905134, 10357432.276347913, 14964237.47108134, 20799832.43777048, 15184832.316707665, 10077201.571271645, 10203751.199046154, 7849832.915715527, 11848638.900977818, 25522720.47383886], "yaxis": "y"}],                        {"legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111 ...

# %%
cauchuY_10 = backtest[["ngay", "predict"]]
cauchuY_10.columns = ["ngay", "cauchuY"]
cauchuY_20_11 = backtest_11[["ngay", "predict"]]
cauchuY_20_11.columns = ["ngay", "cauchuY"]

# %%
cauchuY_12 = predict_next(data_df,best_params,"doanhthu",41)

# %%
cauchuY_12 = cauchuY_12[["ds", "predict"]]
cauchuY_12.columns = ["ds", "cauchuY"]

# %% [markdown]
# ## TranNao

# %%
tranao = store[store.macuahang==18]

# %%
firstday = dt.datetime.strptime('2019/1/1', '%Y/%m/%d').date()
lastday = dt.datetime.strptime('2020/9/30', '%Y/%m/%d').date()

# %%
date_period = pd.date_range(firstday, lastday- dt.timedelta(days = 61))
date_period1 = pd.date_range(lastday- dt.timedelta(days = 60), lastday- dt.timedelta(days = 30))
date_period2 = pd.date_range(lastday- dt.timedelta(days = 29), lastday)

# %%
all_prediod =  pd.date_range(firstday, lastday)
date_test_period =  pd.date_range(dt.datetime.strptime('2020/10/1', '%Y/%m/%d').date(), dt.datetime.strptime('2020/10/31', '%Y/%m/%d').date() )
date_11 =  pd.date_range(dt.datetime.strptime('2020/11/1', '%Y/%m/%d').date(), dt.datetime.strptime('2020/11/20', '%Y/%m/%d').date() )

# %%
date_df =pd.DataFrame(pd.date_range(firstday, dt.datetime.strptime('2020/11/20', '%Y/%m/%d').date() ), columns = ["ngay"])
data_df = date_df.merge(tranao[["ngay", "doanhthu"]], on = "ngay", how = "left")
# date_df.comlumns

# %%
data_df["nfl_sunday"] = data_df['ngay'].apply(nfl_sunday)
data_df["nfl_monday"] = data_df['ngay'].apply(nfl_monday)

# %%
train = data_df[data_df.ngay.isin(list(date_period)+list(date_period1) + list(date_period2))]
test = data_df[data_df.ngay.isin(date_period2)].reset_index().drop(["index"], axis=1)

# %%
all_data = data_df[data_df.ngay.isin(all_prediod)].reset_index().drop(["index"], axis=1)
all_data_10 = data_df[data_df.ngay.isin(pd.date_range(firstday,dt.datetime.strptime('2020/10/31', '%Y/%m/%d').date()))].reset_index().drop(["index"], axis=1)
backtest = data_df[data_df.ngay.isin(date_test_period)].reset_index().drop(["index"], axis=1)
backtest_11 = data_df[data_df.ngay.isin(date_11)].reset_index().drop(["index"], axis=1)

# %%
error = onecolfcst("doanhthu", params = params)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f24533af198>
#  14%|█▍        | 1/7 [00:02<00:12,  2.04s/it]
# [3, 5, 10, 0.5, 10, 0.5] 0.31821894700374986
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f24534fb7b8>
#  29%|██▊       | 2/7 [00:04<00:10,  2.18s/it]
# [25, 25, 50, 0.1, 10, 0.1] 0.29048845599261147
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f24532c9e80>
#  43%|████▎     | 3/7 [00:07<00:09,  2.41s/it]
# [50, 30, 60, 0.3, 10, 0.3] 0.33862408010963396
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f24534dfa20>
#  57%|█████▋    | 4/7 [00:09<00:06,  2.32s/it]
# [2, 4, 8, 0.8, 10, 0.8] 0.330967556932309
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f24553fd940>
#  71%|███████▏  | 5/7 [00:11<00:04,  2.20s/it]
# [2, 2, 4, 0.8, 10, 0.8] 0.2573732844259849
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f24534df780>
#  86%|████████▌ | 6/7 [00:13<00:02,  2.18s/it]INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f24533e8ac8>
# [2, 3, 25, 0.1, 10, 0.1] 0.27574516754615414
# 100%|██████████| 7/7 [00:15<00:00,  2.23s/it]
# [5, 2, 2, 0.5, 0.3, 0.01] 0.1843378025516163

# %%
best_params = [2, 3, 2, 0.6, 5, 0.7]

# %%
# best_params = error[error.rmse == error.rmse.min()].params.values[0]
backtest["predict"] = predict_model(all_data, backtest,best_params, "doanhthu")

# %%
fig = px.line(backtest, x="ngay", y=["doanhthu","predict"])
fig.show()
# Out:
# <div>                            <div id="ae715ac3-3fd7-447e-be08-52ad42a7914e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae715ac3-3fd7-447e-be08-52ad42a7914e")) {                    Plotly.newPlot(                        "ae715ac3-3fd7-447e-be08-52ad42a7914e",                        [{"hovertemplate": "variable=doanhthu<br>ngay=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "doanhthu", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "doanhthu", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-10-01T00:00:00", "2020-10-02T00:00:00", "2020-10-03T00:00:00", "2020-10-04T00:00:00", "2020-10-05T00:00:00", "2020-10-06T00:00:00", "2020-10-07T00:00:00", "2020-10-08T00:00:00", "2020-10-09T00:00:00", "2020-10-10T00:00:00", "2020-10-11T00:00:00", "2020-10-12T00:00:00", "2020-10-13T00:00:00", "2020-10-14T00:00:00", "2020-10-15T00:00:00", "2020-10-16T00:00:00", "2020-10-17T00:00:00", "2020-10-18T00:00:00", "2020-10-19T00:00:00", "2020-10-20T00:00:00", "2020-10-21T00:00:00", "2020-10-22T00:00:00", "2020-10-23T00:00:00", "2020-10-24T00:00:00", "2020-10-25T00:00:00", "2020-10-26T00:00:00", "2020-10-27T00:00:00", "2020-10-28T00:00:00", "2020-10-29T00:00:00", "2020-10-30T00:00:00", "2020-10-31T00:00:00"], "xaxis": "x", "y": [96642050.0, 125564854.0, 116952560.0, 78452740.0, 62849670.0, 94822100.0, 93235400.0, 96407050.0, 112052920.0, 137978336.0, 96605300.0, 73570860.9, 92200376.0, 79525785.0, 94565164.0, 129202200.0, 125984261.0, 82085100.0, 73590070.0, 126979460.0, 58493610.5, 72916920.0, 104328510.0, 125099725.0, 77025832.0, 60663175.0, 78544600.0, 65794337.0, 83904930.0, 116616280.0, 123500370.0], "yaxis": "y"}, {"hovertemplate": "variable=predict<br>ngay=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "predict", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "predict", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-10-01T00:00:00", "2020-10-02T00:00:00", "2020-10-03T00:00:00", "2020-10-04T00:00:00", "2020-10-05T00:00:00", "2020-10-06T00:00:00", "2020-10-07T00:00:00", "2020-10-08T00:00:00", "2020-10-09T00:00:00", "2020-10-10T00:00:00", "2020-10-11T00:00:00", "2020-10-12T00:00:00", "2020-10-13T00:00:00", "2020-10-14T00:00:00", "2020-10-15T00:00:00", "2020-10-16T00:00:00", "2020-10-17T00:00:00", "2020-10-18T00:00:00", "2020-10-19T00:00:00", "2020-10-20T00:00:00", "2020-10-21T00:00:00", "2020-10-22T00:00:00", "2020-10-23T00:00:00", "2020-10-24T00:00:00", "2020-10-25T00:00:00", "2020-10-26T00:00:00", "2020-10-27T00:00:00", "2020-10-28T00:00:00", "2020-10-29T00:00:00", "2020-10-30T00:00:00", "2020-10-31T00:00:00"], "xaxis": "x", "y": [84371716.0686014, 104959938.90177585, 121109974.61286774, 83329931.98562412, 76282668.66848068, 80627314.61152434, 78323792.26010412, 86145060.03124486, 106754998.14187592, 122925851.70291767, 85165696.17693943, 78137357.19620998, 82499934.04083224, 80213319.8704382, 88050445.23793851, 108675163.95300329, 124859696.20973504, 99939736.97864325, 81773161.27617086, 114796924.70491603, 82190415.61954547, 90035390.66138387, 110666740.58071516, 126856671.8675456, 89113224.57550032, 82099192.18568397, 86473645.12597091, 84196451.04087305, 92040518.33863755, 112669682.08445506, 128856147.15286103], "yaxis": "y"}],                        {"legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolo ...

# %%
print("Doanh thu thuc te", backtest.doanhthu.sum())
print("Doanh thu du doan", backtest.predict.sum())
diff_percent = (backtest.doanhthu.sum() - backtest.predict.sum())/backtest.doanhthu.sum()
print("diff_percent", diff_percent)
print("mape", mean_absolute_percentage_error(backtest.doanhthu, backtest.predict))
print("rmse", mean_squared_error(backtest.doanhthu, backtest.predict, squared=False))
# Out:
# Doanh thu thuc te 2956154546.4
# Doanh thu du doan 2974140761.8630157
# diff_percent -0.006084328535840299
# mape 12.61429884106692
# rmse 12496922.262735879

# %%
backtest_11["predict"] = predict_model(all_data_10, backtest_11,best_params, "doanhthu")
(backtest_11.doanhthu.sum() - backtest_11.predict.sum())/backtest_11.doanhthu.sum()
# Out:
# -0.03564052867201861

# %%
print("Doanh thu thuc te", backtest_11.doanhthu.sum())
print("Doanh thu du doan", backtest_11.predict.sum())
diff_percent = (backtest_11.doanhthu.sum() - backtest_11.predict.sum())/backtest_11.doanhthu.sum()
print("diff_percent", diff_percent)
print("mape", mean_absolute_percentage_error(backtest_11.doanhthu, backtest_11.predict))
print("rmse", mean_squared_error(backtest_11.doanhthu, backtest_11.predict, squared=False))
# Out:
# Doanh thu thuc te 1868598063.5
# Doanh thu du doan 1935195886.3586502
# diff_percent -0.03564052867201861
# mape 10.612364249361809
# rmse 11374600.910552347

# %%
fig = px.line(backtest_11, x="ngay", y=["doanhthu","predict"])
fig.show()
# Out:
# <div>                            <div id="0d00b802-48e7-4847-a921-d703d197043f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d00b802-48e7-4847-a921-d703d197043f")) {                    Plotly.newPlot(                        "0d00b802-48e7-4847-a921-d703d197043f",                        [{"hovertemplate": "variable=doanhthu<br>ngay=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "doanhthu", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "doanhthu", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-11-01T00:00:00", "2020-11-02T00:00:00", "2020-11-03T00:00:00", "2020-11-04T00:00:00", "2020-11-05T00:00:00", "2020-11-06T00:00:00", "2020-11-07T00:00:00", "2020-11-08T00:00:00", "2020-11-09T00:00:00", "2020-11-10T00:00:00", "2020-11-11T00:00:00", "2020-11-12T00:00:00", "2020-11-13T00:00:00", "2020-11-14T00:00:00", "2020-11-15T00:00:00", "2020-11-16T00:00:00", "2020-11-17T00:00:00", "2020-11-18T00:00:00", "2020-11-19T00:00:00", "2020-11-20T00:00:00"], "xaxis": "x", "y": [81747996.0, 73428845.0, 64460275.0, 76428080.0, 98685960.0, 119126137.5, 126230835.0, 87463127.0, 104156800.0, 98650560.0, 75016015.0, 88630280.0, 108908310.0, 136434460.0, 91569110.0, 65576808.0, 82463920.0, 80693780.0, 84325775.0, 124600990.0], "yaxis": "y"}, {"hovertemplate": "variable=predict<br>ngay=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "predict", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "predict", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-11-01T00:00:00", "2020-11-02T00:00:00", "2020-11-03T00:00:00", "2020-11-04T00:00:00", "2020-11-05T00:00:00", "2020-11-06T00:00:00", "2020-11-07T00:00:00", "2020-11-08T00:00:00", "2020-11-09T00:00:00", "2020-11-10T00:00:00", "2020-11-11T00:00:00", "2020-11-12T00:00:00", "2020-11-13T00:00:00", "2020-11-14T00:00:00", "2020-11-15T00:00:00", "2020-11-16T00:00:00", "2020-11-17T00:00:00", "2020-11-18T00:00:00", "2020-11-19T00:00:00", "2020-11-20T00:00:00"], "xaxis": "x", "y": [87888104.40622447, 80785210.08126493, 85534556.92593478, 82903231.37703262, 90662325.90460885, 111899649.12695089, 127406537.19710463, 89008143.37874907, 81880035.80757394, 86603328.30848506, 83945135.03720877, 91676577.48203987, 112885494.5452283, 128363253.89476155, 89935041.50295086, 82776459.3701535, 87468656.30202025, 93578815.9809074, 92585730.20501162, 147409599.52443892], "yaxis": "y"}],                        {"legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0 ...

# %%
trannao_10 = backtest[["ngay", "predict"]]
trannao_10.columns = ["ngay", "trannao"]
trannao_20_11 = backtest_11[["ngay", "predict"]]
trannao_20_11.columns = ["ngay", "trannao"]

# %%
trannao_12 = predict_next(data_df,best_params,"doanhthu",41)

# %%
trannao_12 = trannao_12[["ds", "predict"]]
trannao_12.columns = ["ds", "trannao"]

# %% [markdown]
# ## nguyentriphuong

# %%
nguyentriphuong = store[store.macuahang==19]

# %%
tranao
# Out:
#       macuahang               tencuahang       ngay  soluonghoadon  soluongkhach     doanhso  giamgiamon  giamgiahoadon  giamgiathanhvien        vat  phuphi    doanhthu  dow
# 2329  19         ICool Nguy?n Tri Ph??ng 2018-02-04  29             141           23819700.0  349000.0    15000.0        296680.0          0.00       0       23159020.0  6
# 2345  19         ICool Nguy?n Tri Ph??ng 2018-02-05  27             110           13179900.0  0.0         0.0            115005.0          0.00       0       13064895.0  0
# 2361  19         ICool Nguy?n Tri Ph??ng 2018-02-06  30             136           19341700.0  500000.0    0.0            134680.0          178160.00  0       18707020.0  1
# 2377  19         ICool Nguy?n Tri Ph??ng 2018-02-07  20             93            13963300.0  376000.0    124910.0       58670.0           0.00       150000  13403720.0  2
# 2393  19         ICool Nguy?n Tri Ph??ng 2018-02-08  37             181           23196800.0  1044000.0   120870.0       331470.0          0.00       0       21700460.0  3
# ...   ..                             ...        ...  ..             ...                  ...        ...        ...            ...           ...      ..              ... ..
# 579   19         ICool Nguy?n Tri Ph??ng 2020-10-20  23             110           18904400.0  250000.0    282150.0       0.0               0.00       0       18372250.0  1
# 580   19         ICool Nguy?n Tri Ph??ng 2020-10-21  16             80            11296800.0  0.0         0.0            0.0               0.00       0       11296800.0  2
# 581   19         ICool Nguy?n Tri Ph??ng 2020-10-22  7              40            6043200.0   186480.0    0.0            0.0               0.00       0       5856720.0   3
# 582   19         ICool Nguy?n Tri Ph??ng 2020-10-23  14             84            14112800.0  151620.0    113280.0       79625.0           75643.75   0       13768275.0  4
# 583   19         ICool Nguy?n Tri Ph??ng 2020-10-24  26             162           26424400.0  1717402.0   328000.0       0.0               121625.00  0       24378998.0  5
#
# [913 rows x 13 columns]

# %%
firstday = dt.datetime.strptime('2019/1/1', '%Y/%m/%d').date()
lastday = dt.datetime.strptime('2020/9/30', '%Y/%m/%d').date()

# %%
date_period = pd.date_range(firstday, lastday- dt.timedelta(days = 61))
date_period1 = pd.date_range(lastday- dt.timedelta(days = 60), lastday- dt.timedelta(days = 30))
date_period2 = pd.date_range(lastday- dt.timedelta(days = 29), lastday)

# %%
all_prediod =  pd.date_range(firstday, lastday)
date_test_period =  pd.date_range(dt.datetime.strptime('2020/10/1', '%Y/%m/%d').date(), dt.datetime.strptime('2020/10/31', '%Y/%m/%d').date() )
date_11 =  pd.date_range(dt.datetime.strptime('2020/11/1', '%Y/%m/%d').date(), dt.datetime.strptime('2020/11/20', '%Y/%m/%d').date() )

# %%
date_df =pd.DataFrame(pd.date_range(firstday, dt.datetime.strptime('2020/11/20', '%Y/%m/%d').date() ), columns = ["ngay"])
data_df = date_df.merge(nguyentriphuong[["ngay", "doanhthu"]], on = "ngay", how = "left")
# date_df.comlumns

# %%
data_df["nfl_sunday"] = data_df['ngay'].apply(nfl_sunday)
data_df["nfl_monday"] = data_df['ngay'].apply(nfl_monday)

# %%
train = data_df[data_df.ngay.isin(list(date_period)+list(date_period1) + list(date_period2))]
test = data_df[data_df.ngay.isin(date_period2)].reset_index().drop(["index"], axis=1)

# %%
all_data = data_df[data_df.ngay.isin(all_prediod)].reset_index().drop(["index"], axis=1)
all_data_10 = data_df[data_df.ngay.isin(pd.date_range(firstday,dt.datetime.strptime('2020/10/31', '%Y/%m/%d').date()))].reset_index().drop(["index"], axis=1)
backtest = data_df[data_df.ngay.isin(date_test_period)].reset_index().drop(["index"], axis=1)
backtest_11 = data_df[data_df.ngay.isin(date_11)].reset_index().drop(["index"], axis=1)

# %%
error = onecolfcst("doanhthu", params = params)
# Out:
#   0%|          | 0/7 [00:00<?, ?it/s]INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f24550869b0>
#  14%|█▍        | 1/7 [00:02<00:14,  2.45s/it]
# [3, 5, 10, 0.5, 10, 0.5] 0.489749443374825
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f24554b8dd8>
#  29%|██▊       | 2/7 [00:05<00:12,  2.51s/it]
# [25, 25, 50, 0.1, 10, 0.1] 0.5201464767780488
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f245530d278>
#  43%|████▎     | 3/7 [00:09<00:11,  2.97s/it]
# [50, 30, 60, 0.3, 10, 0.3] 0.5282658128012084
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f24553810f0>
#  57%|█████▋    | 4/7 [00:11<00:08,  2.85s/it]
# [2, 4, 8, 0.8, 10, 0.8] 0.49620865916507445
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f24553ae470>
#  71%|███████▏  | 5/7 [00:13<00:05,  2.64s/it]
# [2, 2, 4, 0.8, 10, 0.8] 0.5056066076038046
# INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f245530d518>
#  86%|████████▌ | 6/7 [00:15<00:02,  2.45s/it]INFO:fbprophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7f245341f7f0>
# [2, 3, 25, 0.1, 10, 0.1] 0.5151487090708731
# 100%|██████████| 7/7 [00:17<00:00,  2.52s/it]
# [5, 2, 2, 0.5, 0.3, 0.01] 0.667464181373768

# %%
best_params = [3, 3, 2, 0.6, 9, 0.6]

# %%
# best_params = error[error.rmse == error.rmse.min()].params.values[0]
backtest["predict"] = predict_model(all_data, backtest,best_params, "doanhthu")

# %%
fig = px.line(backtest, x="ngay", y=["doanhthu","predict"])
fig.show()
# Out:
# <div>                            <div id="6adc47e1-1570-408d-95f1-00ff1916eb07" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6adc47e1-1570-408d-95f1-00ff1916eb07")) {                    Plotly.newPlot(                        "6adc47e1-1570-408d-95f1-00ff1916eb07",                        [{"hovertemplate": "variable=doanhthu<br>ngay=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "doanhthu", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "doanhthu", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-10-01T00:00:00", "2020-10-02T00:00:00", "2020-10-03T00:00:00", "2020-10-04T00:00:00", "2020-10-05T00:00:00", "2020-10-06T00:00:00", "2020-10-07T00:00:00", "2020-10-08T00:00:00", "2020-10-09T00:00:00", "2020-10-10T00:00:00", "2020-10-11T00:00:00", "2020-10-12T00:00:00", "2020-10-13T00:00:00", "2020-10-14T00:00:00", "2020-10-15T00:00:00", "2020-10-16T00:00:00", "2020-10-17T00:00:00", "2020-10-18T00:00:00", "2020-10-19T00:00:00", "2020-10-20T00:00:00", "2020-10-21T00:00:00", "2020-10-22T00:00:00", "2020-10-23T00:00:00", "2020-10-24T00:00:00", "2020-10-25T00:00:00", "2020-10-26T00:00:00", "2020-10-27T00:00:00", "2020-10-28T00:00:00", "2020-10-29T00:00:00", "2020-10-30T00:00:00", "2020-10-31T00:00:00"], "xaxis": "x", "y": [24668740.0, 26549400.0, 30454640.0, 15868200.0, 8953890.0, 5977040.0, 14797910.0, 7917100.0, 19624560.0, 36700300.0, 18544200.0, 10270400.0, 14509600.0, 16226900.0, 15249300.0, 21306264.0, 30987360.0, 19782025.0, 9739600.0, 18372250.0, 11296800.0, 5856720.0, 13768275.0, 24378998.0, 8990400.0, 1652000.0, 7122020.0, 3604000.0, 7297000.0, 20751800.0, 14100030.0], "yaxis": "y"}, {"hovertemplate": "variable=predict<br>ngay=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "predict", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "predict", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-10-01T00:00:00", "2020-10-02T00:00:00", "2020-10-03T00:00:00", "2020-10-04T00:00:00", "2020-10-05T00:00:00", "2020-10-06T00:00:00", "2020-10-07T00:00:00", "2020-10-08T00:00:00", "2020-10-09T00:00:00", "2020-10-10T00:00:00", "2020-10-11T00:00:00", "2020-10-12T00:00:00", "2020-10-13T00:00:00", "2020-10-14T00:00:00", "2020-10-15T00:00:00", "2020-10-16T00:00:00", "2020-10-17T00:00:00", "2020-10-18T00:00:00", "2020-10-19T00:00:00", "2020-10-20T00:00:00", "2020-10-21T00:00:00", "2020-10-22T00:00:00", "2020-10-23T00:00:00", "2020-10-24T00:00:00", "2020-10-25T00:00:00", "2020-10-26T00:00:00", "2020-10-27T00:00:00", "2020-10-28T00:00:00", "2020-10-29T00:00:00", "2020-10-30T00:00:00", "2020-10-31T00:00:00"], "xaxis": "x", "y": [12277012.428331362, 18427962.004794784, 24097689.69765716, 18255849.119907852, 9601543.406956486, 10823269.900646638, 10576579.134422205, 12386856.38632554, 18541800.602812093, 24215535.9920229, 18377709.3700911, 9727417.069869183, 10953149.63390421, 10710450.807945384, 12524699.10281673, 18683586.726684637, 24361231.18701519, 19021041.127918918, 8873970.386451114, 18724513.862090386, 10871306.702365369, 12689193.785723569, 18851646.920123704, 24532777.410370816, 18702219.319132123, 10059056.391876072, 11291766.765881117, 11055881.97966966, 12876768.550447252, 19042106.921827998, 24726003.08068052], "yaxis": "y"}],                        {"legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", ...

# %%
print("Doanh thu thuc te", backtest.doanhthu.sum())
print("Doanh thu du doan", backtest.predict.sum())
diff_percent = (backtest.doanhthu.sum() - backtest.predict.sum())/backtest.doanhthu.sum()
print("diff_percent", diff_percent)
print("mape", mean_absolute_percentage_error(backtest.doanhthu, backtest.predict))
print("rmse", mean_squared_error(backtest.doanhthu, backtest.predict, squared=False))
# Out:
# Doanh thu thuc te 485317722.0
# Doanh thu du doan 485860595.776762
# diff_percent -0.0011185945869127125
# mape 53.57304704381259
# rmse 5806124.342198839

# %%
backtest_11["predict"] = predict_model(all_data_10, backtest_11,best_params, "doanhthu")
(backtest_11.doanhthu.sum() - backtest_11.predict.sum())/backtest_11.doanhthu.sum()
# Out:
# -0.09801392231591469

# %%
print("Doanh thu thuc te", backtest_11.doanhthu.sum())
print("Doanh thu du doan", backtest_11.predict.sum())
diff_percent = (backtest_11.doanhthu.sum() - backtest_11.predict.sum())/backtest_11.doanhthu.sum()
print("diff_percent", diff_percent)
print("mape", mean_absolute_percentage_error(backtest_11.doanhthu, backtest_11.predict))
print("rmse", mean_squared_error(backtest_11.doanhthu, backtest_11.predict, squared=False))
# Out:
# Doanh thu thuc te 261686255.0
# Doanh thu du doan 287335151.26871264
# diff_percent -0.09801392231591469
# mape 40.90824062309714
# rmse 4726468.473533656

# %%
fig = px.line(backtest_11, x="ngay", y=["doanhthu","predict"])
fig.show()
# Out:
# <div>                            <div id="2719def2-ec06-472e-ac0c-67c7414b392b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2719def2-ec06-472e-ac0c-67c7414b392b")) {                    Plotly.newPlot(                        "2719def2-ec06-472e-ac0c-67c7414b392b",                        [{"hovertemplate": "variable=doanhthu<br>ngay=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "doanhthu", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "doanhthu", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-11-01T00:00:00", "2020-11-02T00:00:00", "2020-11-03T00:00:00", "2020-11-04T00:00:00", "2020-11-05T00:00:00", "2020-11-06T00:00:00", "2020-11-07T00:00:00", "2020-11-08T00:00:00", "2020-11-09T00:00:00", "2020-11-10T00:00:00", "2020-11-11T00:00:00", "2020-11-12T00:00:00", "2020-11-13T00:00:00", "2020-11-14T00:00:00", "2020-11-15T00:00:00", "2020-11-16T00:00:00", "2020-11-17T00:00:00", "2020-11-18T00:00:00", "2020-11-19T00:00:00", "2020-11-20T00:00:00"], "xaxis": "x", "y": [15224360.0, 10469620.0, 4562900.0, 7210100.0, 14295360.0, 17381990.0, 21058050.0, 14893240.0, 9599340.0, 11406480.0, 6381740.0, 8329000.0, 28146580.0, 33158085.0, 8089850.0, 5427200.0, 4464200.0, 10605560.0, 6946720.0, 24035880.0], "yaxis": "y"}, {"hovertemplate": "variable=predict<br>ngay=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "predict", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "predict", "orientation": "v", "showlegend": true, "type": "scatter", "x": ["2020-11-01T00:00:00", "2020-11-02T00:00:00", "2020-11-03T00:00:00", "2020-11-04T00:00:00", "2020-11-05T00:00:00", "2020-11-06T00:00:00", "2020-11-07T00:00:00", "2020-11-08T00:00:00", "2020-11-09T00:00:00", "2020-11-10T00:00:00", "2020-11-11T00:00:00", "2020-11-12T00:00:00", "2020-11-13T00:00:00", "2020-11-14T00:00:00", "2020-11-15T00:00:00", "2020-11-16T00:00:00", "2020-11-17T00:00:00", "2020-11-18T00:00:00", "2020-11-19T00:00:00", "2020-11-20T00:00:00"], "xaxis": "x", "y": [17707760.63256161, 9075876.603741135, 10311997.557775177, 10157912.157971788, 11898860.824446538, 18162135.016867794, 23896968.7358512, 17695574.869317733, 9064497.884529386, 10301355.884693684, 10147934.693634562, 11889472.007360838, 18153256.680673666, 23888520.232250694, 17687473.194297466, 9056657.80815523, 10293690.083936363, 10937543.374856034, 11180545.016186178, 25827118.009605534], "yaxis": "y"}],                        {"legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d088 ...

# %%
nguyentriphuong_10 = backtest[["ngay", "predict"]]
nguyentriphuong_10.columns = ["ngay", "nguyentriphuong"]
nguyentriphuong_20_11 = backtest_11[["ngay", "predict"]]
nguyentriphuong_20_11.columns = ["ngay", "nguyentriphuong"]

# %%
nguyentriphuong_12 = predict_next(data_df,best_params,"doanhthu",41)

# %%
nguyentriphuong_12 = nguyentriphuong_12[["ds", "predict"]]
nguyentriphuong_12.columns = ["ds", "nguyentriphuong"]

# %%
total = ungvankhiem_12.merge(xvnt_12, on = "ds").merge(toky_12, on = "ds").merge(binhphu_12,on ="ds").merge(cauchuY_12,on = "ds").merge(trannao_12, on ="ds").merge(nguyentriphuong_12, on ="ds")

# %%
total.to_csv("revenue_12_new.csv", index=False)

# %%
total_10 = ungvankhiem_10.merge(xvnt_10, on = "ngay").merge(toky_10, on = "ngay").merge(binhphu_10,on ="ngay").merge(cauchuY_10,on = "ngay").merge(trannao_10, on ="ngay").merge(nguyentriphuong_10, on ="ngay")

# %%
total_10.to_csv("revenue_10_new.csv", index=False)

# %%
total_20_11 = ungvankhiem_20_11.merge(xvnt_20_11, on = "ngay").merge(toky_20_11, on = "ngay").merge(binhphu_20_11,on ="ngay").merge(cauchuY_20_11,on = "ngay").merge(trannao_20_11, on ="ngay").merge(nguyentriphuong_20_11, on ="ngay")

# %%
total_20_11.to_csv("revenue_20_11_new.csv", index=False)
